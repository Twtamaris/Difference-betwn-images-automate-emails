# %%
from PIL import Image, ImageChops

# %%
img1, img2 = Image.open('1.jpg'), Image.open('2.jpg')

# %%
diff = ImageChops.difference(img1, img2)

if diff.getbbox():
    diff.show()
    x = diff

else:
    print('No Difference found')
    print('Images are same')

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x385 at 0x18C16DB52B0>

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x385 at 0x18C16F49490>

# %%
diff
# The Figure Below is the difference between img1, img2
# Out:
# <PIL.Image.Image image mode=RGB size=349x385 at 0x18C16EC6A30>
